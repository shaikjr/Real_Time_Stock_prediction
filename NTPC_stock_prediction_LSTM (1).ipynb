# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

df = pd.read_csv("/content/dav project dataset.csv")

df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    05-11-2004  73.333336  73.333336  58.333332  62.958332  34.687588
# 1    08-11-2004  64.000000  65.500000  62.500000  62.666664  34.526894
# 2    09-11-2004  62.583332  63.416664  62.125000  62.750000  34.572815
# 3    10-11-2004  62.916664  63.291664  62.500000  62.541664  34.458023
# 4    11-11-2004  62.791664  62.833332  61.916664  62.041664  34.182541
# ..          ...        ...        ...        ...        ...        ...
# 195  11-08-2005  81.583336  81.583336  80.583336  80.875000  45.136108
# 196  12-08-2005  80.875000  81.250000  79.750000  80.125000  44.717525
# 197  16-08-2005  83.333336  83.333336  80.041664  80.791664  45.089592
# 198  17-08-2005  80.250000  81.041664  79.791664  80.791664  45.089592
# 199  18-08-2005  81.041664  81.708336  80.708336  81.166664  45.298878
#
#         Volume
# 0    279042883
# 1     82638332
# 2     44953063
# 3     20896119
# 4     19153711
# ..         ...
# 195    4261576
# 196    3501807
# 197    5892031
# 198    4096611
# 199    6926876
#
# [200 rows x 7 columns]

# %%
x_1=df['Date']
x_1
# Out:
# 0      05-11-2004
# 1      08-11-2004
# 2      09-11-2004
# 3      10-11-2004
# 4      11-11-2004
#           ...
# 195    11-08-2005
# 196    12-08-2005
# 197    16-08-2005
# 198    17-08-2005
# 199    18-08-2005
# Name: Date, Length: 200, dtype: object

# %%
x_2=df['Low']
x_2
# Out:
# 0      58.333332
# 1      62.500000
# 2      62.125000
# 3      62.500000
# 4      61.916664
#          ...
# 195    80.583336
# 196    79.750000
# 197    80.041664
# 198    79.791664
# 199    80.708336
# Name: Low, Length: 200, dtype: float64

# %%
x_3=df['High']
x_3
# Out:
# 0      73.333336
# 1      65.500000
# 2      63.416664
# 3      63.291664
# 4      62.833332
#          ...
# 195    81.583336
# 196    81.250000
# 197    83.333336
# 198    81.041664
# 199    81.708336
# Name: High, Length: 200, dtype: float64

# %%
x_4=df['Close']
x_4
# Out:
# 0      62.958332
# 1      62.666664
# 2      62.750000
# 3      62.541664
# 4      62.041664
#          ...
# 195    80.875000
# 196    80.125000
# 197    80.791664
# 198    80.791664
# 199    81.166664
# Name: Close, Length: 200, dtype: float64

# %%
x_5=df['Volume']
x_5
# Out:
# 0      279042883
# 1       82638332
# 2       44953063
# 3       20896119
# 4       19153711
#          ...
# 195      4261576
# 196      3501807
# 197      5892031
# 198      4096611
# 199      6926876
# Name: Volume, Length: 200, dtype: int64

# %%
x_6=df['Adj Close']
x_6
# Out:
# 0      34.687588
# 1      34.526894
# 2      34.572815
# 3      34.458023
# 4      34.182541
#          ...
# 195    45.136108
# 196    44.717525
# 197    45.089592
# 198    45.089592
# 199    45.298878
# Name: Adj Close, Length: 200, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])
#plt.plot(x, y)

# %%
sns.pairplot(data=df,kind="scatter")

# %%
plt.scatter(x_1,x_2)

# %%
plt.scatter(x_1,x_3)

# %%
plt.scatter(x_1,x_4)

# %%
plt.scatter(x_1,x_5)

# %%
plt.plot(x_1,x_6)

# %%
plt.scatter(x_1,x_4,color='red')
plt.plot(x_1,x_6,color='green')
plt.show()
